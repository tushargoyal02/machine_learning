# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df =pd.read_csv("/home/tushar/Desktop/FDP/pandas/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# 10    11            5.4           3.7            1.5           0.2
# 11    12            4.8           3.4            1.6           0.2
# 12    13            4.8           3.0            1.4           0.1
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.plot(x='SepalLengthCm',y='SepalWidthCm')

# %%
df.plot(x='SepalLengthCm',y='SepalWidthCm', kind='scatter')

# %%
df.plot(y='SepalLengthCm', kind='hist')

# %%
df.plot(kind='hist', bins=50, range=(0,8), alpha=0.3)

# %%
indices = df['Species'] == 'Iris-setosa'

# %%
sentosa = df.loc[indices,:]

# %%
sentosa.plot(kind='hist', bins=50)

# %%
describe_sentosa = sentosa.describe()

# %%
describe_all = df.describe()

# %%
error_setosa = 100 * np.abs(describe_sentosa - describe_all)

# %%
error_setosa
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  10000.000000   10000.000000  10000.000000   10000.000000  10000.000000
# mean    5000.000000      83.733333     36.400000     229.466667     95.466667
# std     2886.798826      47.557644      5.256991     159.090926     65.595124
# min        0.000000       0.000000     30.000000       0.000000      0.000000
# 25%     2500.000000      30.000000     32.500000      20.000000     10.000000
# 50%     5000.000000      80.000000     40.000000     285.000000    110.000000
# 75%     7500.000000     120.000000     37.500000     352.500000    150.000000
# max    10000.000000     210.000000      0.000000     500.000000    190.000000
